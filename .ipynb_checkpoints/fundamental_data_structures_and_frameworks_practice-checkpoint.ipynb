# %%
import lamindb as ln
import scanpy as sc
# Out:
# → connected lamindb: anonymous/lamin_storage

# %% [markdown]
# ### Initialized a local LaminDB storage folder

# %%
ln.setup.init(storage="./lamin_storage")
# Out:
# → doing nothing, already connected lamindb: anonymous/lamin_storage
# → connected lamindb: anonymous/lamin_storage

# %% [markdown]
# ### Started tracking my notebook run

# %%
ln.track()
# Out:
# → loaded Transform('aV9wcZ2u9C310000', key='fundamental_data_structures_and_frameworks_practice.ipynb'), re-started Run('TtJEhrfbHik5VJVP') at 2026-03-14 14:24:25 UTC
# → notebook imports: anndata==0.12.7 lamindb==2.2.1 numpy==2.4.2 pandas==2.3.3 scanpy==1.12 scipy==1.16.3
# • recommendation: to identify the notebook across renames, pass the uid: ln.track("aV9wcZ2u9C31")

# %% [markdown]
# ### Downloaded the PBMC3k dataset

# %%
adata = sc.datasets.pbmc3k()
adata.write("fundamental_data_structures_and_frameworks.h5ad")

# %% [markdown]
# ### Saved it as an AnnData artifact

# %%
af = ln.Artifact(
    "fundamental_data_structures_and_frameworks.h5ad",
    key="introduction/fundamental_data_structures_and_frameworks.h5ad",
    description="anndata for fundamental data structures and frameworks",
).save()
af
# Out:
# ! calling anonymously, will miss private instances
# → returning artifact with same hash: Artifact(uid='yXg0EAKjjUVMxpYG0000', version_tag=None, is_latest=True, key='introduction/fundamental_data_structures_and_frameworks.h5ad', description='anndata for fundamental data structures and frameworks', suffix='.h5ad', kind=None, otype='AnnData', size=21474644, hash='C9laTdsBNF8H3--jal8mKw', n_files=None, n_observations=None, branch_id=1, created_on_id=1, space_id=1, storage_id=1, run_id=1, schema_id=None, created_by_id=1, created_at=2026-03-13 16:43:37 UTC, is_locked=False); to track this artifact as an input, use: ln.Artifact.get()
# Artifact(uid='yXg0EAKjjUVMxpYG0000', version_tag=None, is_latest=True, key='introduction/fundamental_data_structures_and_frameworks.h5ad', description='anndata for fundamental data structures and frameworks', suffix='.h5ad', kind=None, otype='AnnData', size=21474644, hash='C9laTdsBNF8H3--jal8mKw', n_files=None, n_observations=None, branch_id=1, created_on_id=1, space_id=1, storage_id=1, run_id=1, schema_id=None, created_by_id=1, created_at=2026-03-13 16:43:37 UTC, is_locked=False)

# %% [markdown]
# ### Initializing an AnnData object

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
import anndata as ad
import lamindb as ln
import numpy as np
import pandas as pd
from scipy.sparse import csr_matrix

ln.track()
# Out:
# → loaded Transform('aV9wcZ2u9C310000', key='fundamental_data_structures_and_frameworks_practice.ipynb'), re-started Run('TtJEhrfbHik5VJVP') at 2026-03-14 14:24:29 UTC
# → notebook imports: anndata==0.12.7 lamindb==2.2.1 numpy==2.4.2 pandas==2.3.3 scanpy==1.12 scipy==1.16.3
# • recommendation: to identify the notebook across renames, pass the uid: ln.track("aV9wcZ2u9C31")

# %% [markdown]
# As a next step, we initialize an AnnData object with random {term}Poisson distributed <Poisson distribution> data. It is an unwritten rule to name the primary AnnData object of the analysis adata

# %%
counts = csr_matrix(
    np.random.default_rng().poisson(1, size=(100, 2000)), dtype=np.float32
)
adata = ad.AnnData(counts)
adata
# Out:
# AnnData object with n_obs × n_vars = 100 × 2000

# %% [markdown]
# The obtained AnnData object has 100 observations and 2000 variables. This would correspond to 100 cells with 2000 genes.
# The initial data we passed are accessible as a sparse matrix using adata.X.

# %%
adata.X
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float32'
# 	with 126808 stored elements and shape (100, 2000)>

# %% [markdown]
# Now, we provide the index to both the obs and var axes using .obs_names and .var_names, respectively.

# %%
adata.obs_names = [f"Cell_{i:d}" for i in range(adata.n_obs)]
adata.var_names = [f"Gene_{i:d}" for i in range(adata.n_vars)]
print(adata.obs_names[:10])
# Out:
# Index(['Cell_0', 'Cell_1', 'Cell_2', 'Cell_3', 'Cell_4', 'Cell_5', 'Cell_6',
#        'Cell_7', 'Cell_8', 'Cell_9'],
#       dtype='object')

# %% [markdown]
# ### Adding aligned metadata

# %% [markdown]
# #### Observational or variable level

# %% [markdown]
# The core of our AnnData object is now in place. As a next step, we add metadata at both the observational and variable levels. Remember, we store such annotations in the .obs and .var slots of the AnnData object for cell and gene annotations, respectively.

# %%
ct = np.random.default_rng().choice(["B", "T", "Monocyte"], size=(adata.n_obs,))
adata.obs["cell_type"] = pd.Categorical(ct)  # Categoricals are preferred for efficiency
adata.obs
# Out:
#         cell_type
# Cell_0   Monocyte
# Cell_1   Monocyte
# Cell_2          T
# Cell_3   Monocyte
# Cell_4          T
# ...           ...
# Cell_95         B
# Cell_96  Monocyte
# Cell_97  Monocyte
# Cell_98         T
# Cell_99         T
#
# [100 rows x 1 columns]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 100 × 2000
#     obs: 'cell_type'

# %% [markdown]
# #### Subsetting using metadata

# %% [markdown]
# We can also subset the AnnData object with the randomly generated cell types.
# The slicing and masking of the AnnData object behaves similarly to the data access in Pandas DataFrames or R matrices.

# %%
bdata = adata[adata.obs.cell_type == "B"]
bdata
# Out:
# View of AnnData object with n_obs × n_vars = 36 × 2000
#     obs: 'cell_type'

# %% [markdown]
# ### Observation/variable-level matrices

# %% [markdown]
# We might also have metadata at either level with many dimensions, such as a UMAP embedding of the data. AnnData has the .obsm/.varm attributes for this type of metadata. We use keys to identify the different matrices we insert. The restriction of .obsm/.varm is that .obsm matrices must
# have a length equal to the number of observations as .n_obs and .varm matrices must have a length equal to .n_vars. They can each independently have a different number of dimensions. Let us start with a randomly generated matrix that we can interpret as a UMAP embedding of the data we would like to store, as well as some random gene-level metadata.

# %%
adata.obsm["X_umap"] = np.random.default_rng().normal(0, 1, size=(adata.n_obs, 2))
adata.varm["gene_stuff"] = np.random.default_rng().normal(0, 1, size=(adata.n_vars, 5))
adata.obsm
# Out:
# AxisArrays with keys: X_umap

# %% [markdown]
# Again, the AnnData representation is updated.

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 100 × 2000
#     obs: 'cell_type'
#     obsm: 'X_umap'
#     varm: 'gene_stuff'

# %% [markdown]
# ### Unstructured metadata

# %% [markdown]
# As mentioned above, AnnData has .uns, which allows for any unstructured metadata.This can be anything, like a list or a dictionary, with some general information that was useful in the analysis of our data. Try only using this slot for data that cannot be efficiently stored in the other slots.

# %%
adata.uns["random"] = [1, 2, 3]
adata.uns
# Out:
# OrderedDict([('random', [1, 2, 3])])

# %% [markdown]
# ### Layers

# %% [markdown]
# Finally, we may have different forms of our original core data, perhaps one that is normalized and one that is not. These can be stored in different layers in AnnData. For example, let us log transform the original data and store it in a layer.

# %%
adata.layers["log_transformed"] = np.log1p(adata.X)
adata
# Out:
# AnnData object with n_obs × n_vars = 100 × 2000
#     obs: 'cell_type'
#     uns: 'random'
#     obsm: 'X_umap'
#     varm: 'gene_stuff'
#     layers: 'log_transformed'

# %% [markdown]
# ### Conversion to DataFrames

# %% [markdown]
# It is possible to obtain a Pandas DataFrame from one of the layers.

# %%
adata.to_df(layer="log_transformed")
# Out:
#            Gene_0    Gene_1    Gene_2    Gene_3    Gene_4    Gene_5    Gene_6  \
# Cell_0   1.098612  0.693147  0.693147  0.693147  0.000000  0.000000  1.098612
# Cell_1   0.000000  0.693147  0.693147  0.000000  0.000000  0.693147  0.693147
# Cell_2   0.693147  0.000000  1.098612  1.098612  1.098612  0.693147  1.386294
# Cell_3   0.000000  0.693147  0.000000  0.000000  0.693147  0.693147  0.693147
# Cell_4   0.693147  1.098612  0.000000  0.000000  0.000000  0.693147  0.693147
# ...           ...       ...       ...       ...       ...       ...       ...
# Cell_95  0.000000  0.693147  1.098612  0.693147  0.000000  1.098612  1.098612
# Cell_96  0.000000  0.693147  0.693147  0.000000  0.000000  0.693147  0.693147
# Cell_97  0.000000  1.098612  1.098612  0.000000  0.693147  0.693147  0.000000
# Cell_98  0.000000  0.000000  0.000000  1.386294  0.693147  0.693147  0.693147
# Cell_99  0.693147  0.000000  1.098612  0.000000  0.000000  0.693147  0.693147
#
#            Gene_7    Gene_8    Gene_9  ...  Gene_1990  Gene_1991  Gene_1992  \
# Cell_0   0.693147  0.000000  1.098612  ...   1.386294   0.693147   0.000000
# Cell_1   0.000000  0.000000  0.693147  ...   0.000000   0.693147   0.693147
# Cell_2   1.098612  0.000000  1.098612  ...   1.609438   0.000000   0.693147
# Cell_3   1.386294  0.000000  0.000000  ...   1.098612   0.693147   1.609438
# Cell_4   0.693147  1.098612  0.693147  ...   0.693147   0.000000   0.693147
# ...           ...       ...       ...  ...        ...        ...        ...
# Cell_95  1.386294  0.000000  0.693147  ...   0.693147   0.000000   1.386294
# Cell_96  0.693147  0.693147  0.693147  ...   1.386294   0.000000   1.098612
# Cell_97  1.098612  1.609438  0.693147  ...   0.693147   0.693147   0.693147
# Cell_98  0.000000  0.693147  0.000000  ...   1.098612   0.693147   1.098612
# Cell_99  0.693147  0.000000  0.000000  ...   0.000000   0.000000   0.000000
#
#          Gene_1993  Gene_1994  Gene_1995  Gene_1996  Gene_1997  Gene_1998  \
# Cell_0    0.000000   0.000000   1.098612   0.000000   0.000000   0.693147
# Cell_1    0.000000   1.386294   1.098612   0.000000   0.693147   1.098612
# Cell_2    0.693147   0.693147   0.693147   1.098612   0.000000   0.693147
# Cell_3    0.693147   0.000000   0.693147   1.386294   0.693147   0.693147
# Cell_4    0.000000   1.386294   0.693147   1.098612   1.098612   0.000000
# ...            ...        ...        ...        ...        ...        ...
# Cell_95   1.098612   0.693147   0.000000   0.693147   1.386294   1.386294
# Cell_96   0.000000   1.098612   0.000000   0.000000   0.693147   0.693147
# Cell_97   1.098612   1.098612   0.693147   0.693147   0.000000   0.000000
# Cell_98   1.098612   0.000000   0.693147   1.609438   1.098612   0.693147
# Cell_99   1.609438   0.000000   1.098612   1.098612   0.693147   0.693147
#
#          Gene_1999
# Cell_0    0.000000
# Cell_1    1.386294
# Cell_2    1.098612
# Cell_3    1.386294
# Cell_4    0.693147
# ...            ...
# Cell_95   1.386294
# Cell_96   1.386294
# Cell_97   0.000000
# Cell_98   0.693147
# Cell_99   0.000000
#
# [100 rows x 2000 columns]

# %% [markdown]
# ### Reading and writing of AnnData objects

# %% [markdown]
# AnnData objects can be saved on disk to hierarchical array stores like [HDF5] or [Zarr]to enable similar structures in disk and on memory.
# AnnData comes with its own persistent HDF5-based file format: `h5ad`.
# If string columns with a few categories are not yet categorical, AnnData will auto-transform them to categorical.
# We will now save our AnnData object in `h5ad` format.

# %%
adata.write("my_results.h5ad", compression="gzip")
adata_new = ad.read_h5ad("my_results.h5ad")
adata_new
# Out:
# AnnData object with n_obs × n_vars = 100 × 2000
#     obs: 'cell_type'
#     uns: 'random'
#     obsm: 'X_umap'
#     varm: 'gene_stuff'
#     layers: 'log_transformed'

# %% [markdown]
# ### Efficient data access

# %% [markdown]
# For the fun of it, let us look at another metadata use case.
# Imagine that the observations come from instruments characterizing 10 readouts in a multi-year study with samples taken from different subjects at different sites.
# We would typically get that information in some format and then store it in a DataFrame:

# %%
obs_meta = pd.DataFrame(
    {
        "time_yr": np.random.default_rng().choice([0, 2, 4, 8], adata.n_obs),
        "subject_id": np.random.default_rng().choice(
            ["subject 1", "subject 2", "subject 4", "subject 8"], adata.n_obs
        ),
        "instrument_type": np.random.default_rng().choice(
            ["type a", "type b"], adata.n_obs
        ),
        "site": np.random.default_rng().choice(["site x", "site y"], adata.n_obs),
    },
    index=adata.obs.index,  # these are the same IDs of observations as above!
)

# %% [markdown]
# This is how we join the readout data with the metadata. Of course, the first argument of the following call for X could also just be a DataFrame.
# This will result in a single data container that tracks everything.

# %%
adata = ad.AnnData(adata.X, obs=obs_meta, var=adata.var)
adata
# Out:
# AnnData object with n_obs × n_vars = 100 × 2000
#     obs: 'time_yr', 'subject_id', 'instrument_type', 'site'

# %% [markdown]
# Similar to numpy arrays, AnnData objects can either hold actual data or reference another `AnnData` object. In the latter case, they are referred to as "view".
# Subsetting AnnData objects always returns views, which has two advantages:
#
# - No new memory is allocated.
# - It is possible to modify the underlying AnnData object.
#
# You can get an actual AnnData object from a view by calling `.copy()` on the view.
# Usually, this is not necessary, as any modification of elements of a view (calling `.[]` on an attribute of the view) internally calls `.copy()` and makes the view an AnnData object that holds actual data.
# See the example below.

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 100 × 2000
#     obs: 'time_yr', 'subject_id', 'instrument_type', 'site'

# %% [markdown]
# Indexing into AnnData will assume that integer arguments to `[]` behave like `.iloc` in pandas, whereas string arguments behave like `.loc`.`AnnData` always assumes string indices.

# %%
adata_view = adata[:5, ["Gene_1", "Gene_3"]]
adata_view
# Out:
# View of AnnData object with n_obs × n_vars = 5 × 2
#     obs: 'time_yr', 'subject_id', 'instrument_type', 'site'

# %% [markdown]
# The dimensions of the AnnData object have not changed. It still contains the same data. If we want an AnnData that holds the data in memory, we must call it `.copy()`.

# %%
adata_subset = adata[:5, ["Gene_1", "Gene_3"]].copy()
adata_subset
# Out:
# AnnData object with n_obs × n_vars = 5 × 2
#     obs: 'time_yr', 'subject_id', 'instrument_type', 'site'

# %% [markdown]
# Partial reading of large data. If a single h5ad file is very large, you can partially read it into memory by using backed mode.

# %%
adata = ad.read_h5ad("my_results.h5ad", backed="r")

# %% [markdown]
# If you do this, you will need to remember that the AnnData object has an open connection to the file used for reading.

# %%
adata.filename
# Out:
# PosixPath('my_results.h5ad')

# %%
adata.file.close()

# %% [markdown]
# ### Unimodal data analysis with scanpy

# %% [markdown]
# More specifically, scanpy is a Python package that builds on top of AnnData to facilitate the analysis of single-cell gene expression data.

# %% [markdown]
# Scanpy is available on PyPI and Conda.
# It can be installed using either of the following commands.
# ```bash
# pip install scanpy
# conda install -c conda-forge scanpy
# ```

# %% [markdown]
# #### Scanpy API design

# %% [markdown]
# The scanpy framework is designed in a way that functions belonging to the same step are grouped into corresponding modules. For example, all preprocessing functions are available in the scanpy.preprocessing module, all transformations of a data matrix that are not preprocessing are available in scanpy.tools, and all visualizations are available in scanpy.plot. These modules are commonly accessed after having imported scanpy like import scanpy as sc with the corresponding abbreviations sc.pp for preprocessing, sc.tl for tools, and sc.pl for plots. All modules which read or write data are directly accessed. Further, a module for various datasets is available as sc.datasets. All functions with corresponding parameters and potential example plots are documented in the scanpy API documentation {cite}scanpy_api.

# %% [markdown]
# #### Scanpy example

# %% [markdown]
# As a first step we import scanpy and define defaults for our following quick scanpy demo.
# We use scanpy's setting object to  set the Matplotlib plotting defaults for all of scanpy's plots and finally print scanpy's header.
# This header contains the versions of all relevant Python packages in the current environment including scanpy and AnnData.
# This output is especially useful when reporting bugs to the scverse team and for reproducibility reasons.

# %%
import scanpy as sc

sc.settings.set_figure_params(dpi=80, facecolor="white")
sc.logging.print_header()
# Out:
# anndata	0.12.7
# lamindb	2.2.1
# scanpy	1.12
# numpy	2.4.2
# pandas	2.3.3
# scipy	1.16.3
# ----	----
# jsonschema	4.26.0
# numcodecs	0.16.5
# certifi	2026.2.25 (2026.02.25)
# Pygments	2.19.2
# lamin_utils	0.16.3
# sniffio	1.3.1
# click	8.3.1
# comm	0.2.3
# fqdn	1.5.1
# natsort	8.4.0
# jsonschema-specifications	2025.9.1
# Brotli	1.2.0
# hyperframe	6.1.0
# nbformat	5.10.4
# yarl	1.23.0
# postgrest	2.24.0
# ipykernel	7.2.0
# sqlparse	0.5.5
# storage3	2.24.0
# markdown-it-py	4.0.0
# mdit-py-plugins	0.5.0
# h5py	3.15.1
# pydantic_core	2.41.5
# Django	5.2.12
# rpds-py	0.30.0
# donfig	0.8.1.post1
# importlib_metadata	8.7.1
# lark	1.3.1
# django-pgtrigger	4.17.0
# webcolors	25.10.0
# cryptography	46.0.5
# cycler	0.12.1
# Jinja2	3.1.6
# prometheus_client	0.24.1
# realtime	2.24.0
# wcwidth	0.6.0
# platformdirs	4.9.4
# pyarrow	23.0.1
# ipython	9.11.0
# MarkupSafe	3.0.3
# supabase-auth	2.24.0
# python-json-logger	2.0.7
# psycopg2-binary	2.9.11 (2.9.11 (dt dec pq3 ext lo64))
# setuptools	82.0.1
# httpx-retries	0.4.6
# zipp	3.23.0
# jedi	0.19.2
# jupytext	1.19.1
# uri-template	1.3.0
# numba	0.64.0
# python-dotenv	1.2.2
# jsonpointer	3.0.0
# supabase	2.24.0
# fastjsonschema	2.21.2
# attrs	25.4.0
# pure_eval	0.2.3
# fsspec	2025.12.0
# httpx	0.28.1
# universal_pathlib	0.2.6
# asttokens	3.0.1
# tornado	6.5.5
# pytz	2025.2
# debugpy	1.8.20
# zarr	3.1.5
# stack_data	0.6.3
# h2	4.3.0
# hpack	4.1.0
# rich	14.3.3
# isoduration	20.11.0
# joblib	1.5.3
# websockets	15.0.1
# pyzmq	27.1.0
# nbproject	0.11.1
# websocket-client	1.9.0
# rfc3339_validator	0.1.4
# legacy-api-wrap	1.5
# h11	0.16.0
# deprecation	2.1.0
# google-crc32c	1.8.0
# pyparsing	3.3.2
# msgpack	1.1.2
# propcache	0.4.1
# psutil	7.2.2
# cffi	2.0.0
# kiwisolver	1.5.0
# mdurl	0.1.2
# python-dateutil	2.9.0.post0
# Send2Trash	2.1.0
# jupyter_server	2.17.0
# httpcore	1.0.9
# scikit-learn	1.8.0
# executing	2.2.1
# session-info2	0.4
# typing_extensions	4.15.0
# jupyter_client	8.8.0
# jupyter_core	5.9.1
# jupyter-events	0.12.0
# traitlets	5.14.3
# prompt_toolkit	3.0.52
# six	1.17.0
# referencing	0.37.0
# supabase-functions	2.24.0
# fast-array-utils	1.3.1
# rfc3986-validator	0.1.1
# PyYAML	6.0.3
# pydantic	2.12.5
# matplotlib-inline	0.2.1
# charset-normalizer	3.4.5
# lamindb_setup	1.22.0
# matplotlib	3.10.8
# typing-inspection	0.4.2
# parso	0.8.6
# arrow	1.4.0
# PyJWT	2.12.0
# asgiref	3.11.1
# defusedxml	0.7.1
# orjson	3.11.7
# decorator	5.2.1
# dj-database-url	2.3.0
# rfc3987-syntax	1.1.0
# idna	3.11
# multidict	6.7.1
# anyio	4.12.1
# threadpoolctl	3.6.0
# llvmlite	0.46.0
# annotated-types	0.7.0
# packaging	26.0
# pillow	12.1.1
# aiobotocore	2.26.0
# ----	----
# Python	3.13.12 | packaged by conda-forge | (main, Feb  5 2026, 05:53:46) [GCC 14.3.0]
# OS	Linux-5.14.0-611.30.1.el9_7.x86_64-x86_64-with-glibc2.34
# CPU	64 logical CPU cores, x86_64
# GPU	No GPU found
# Updated	2026-03-14 14:38

# %% [markdown]
# The dataset of choice is a dataset of 2700 peripheral blood mononuclear cells of a healthy donor which were sequenced on the Illumina NextSeq 500.
# We can load the dataset from `lamindb`, although it is also available via `sc.datasets.pbmc3k()`.

# %%
adata = ln.Artifact.get(
    key="introduction/fundamental_data_structures_and_frameworks.h5ad", is_latest=True
).load()
adata
# Out:
# AnnData object with n_obs × n_vars = 2700 × 32738
#     var: 'gene_ids'

# %% [markdown]
# The returned AnnData object has 2700 cells with 32738 genes.
# The `var` slot further contains the gene IDs.

# %%
adata.var
# Out:
#                      gene_ids
# index
# MIR1302-10    ENSG00000243485
# FAM138A       ENSG00000237613
# OR4F5         ENSG00000186092
# RP11-34P13.7  ENSG00000238009
# RP11-34P13.8  ENSG00000239945
# ...                       ...
# AC145205.1    ENSG00000215635
# BAGE5         ENSG00000268590
# CU459201.1    ENSG00000251180
# AC002321.2    ENSG00000215616
# AC002321.1    ENSG00000215611
#
# [32738 rows x 1 columns]

# %% [markdown]
# As mentioned above, all of scanpy's analysis functions are accessible via `sc.[pp, tl, pl]`.
# As a first step to get an overview over our data, we use scanpy to show those genes that yield the highest fraction of counts in each single cell, across all cells.
# We simply call the `sc.pl.highest_expr_genes` function, pass the AnnData object which is in pretty much all cases the first parameter of any scanpy function, and specify that we want the top 20 expressed genes to be shown.

# %%
sc.pl.highest_expr_genes(adata, n_top=20)

# %% [markdown]
# We now filter cells with less than 200 detected genes and genes which were found in less than 3 cells for a rough quality threshold with scanpy's preprocessing module.

# %%
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)

# %% [markdown]
# A common step in single-cell RNA-Seq analysis is dimensionality reduction with for example PCA to unveil the main axes of variation. This also denoises the data. Scanpy offers PCA as a preprocessing or tools function. These are equivalent. Here, we use the version in tools for no particular reason.

# %%
sc.tl.pca(adata, svd_solver="arpack")

# %% [markdown]
# The corresponding plotting function allows us to pass genes to the color argument.
# The corresponding values are automatically extracted from the AnnData object.

# %%
sc.pl.pca(adata, color="CST3")

# %% [markdown]
# A fundamental step for any advanced embedding and downstream calculations is the calculating of the neighborhood graph using the PCA representation of the data matrix.
# It is automatically used for other tools that require it such as the calculation of a UMAP

# %%
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=40)

# %%
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color=["CST3", "NKG7", "PPBP"])
